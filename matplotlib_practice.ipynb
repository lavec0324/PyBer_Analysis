# %% [markdown]
# # Line Charts 5 - 5.1.4

# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure() # this must be included if changing chart attributes
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create the plot.
plt.plot(x_axis,y_axis, label='test label')
plt.legend()
plt.show()

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="o", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
# Create the plot.
#plt.plot(x_axis, y_axis, marker="o", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
#plt.xlabel("Date")
#plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
#plt.ylim(0, 45)
# Create a title.
#plt.title("PyBer Fare by Month")
# Add a grid.
#plt.grid()
# Add the legend.
#plt.legend()

# Create the plot with ax.plt()
fig = plt.figure() # this must be included if changing chart attributes
#fig, ax = plt.subplots(figsize=(10, 10))
ax = fig.add_subplot()
ax.plot(x_axis, y_axis, "-d",color="green",linewidth=2,label="Boston")
ax.legend()
ax.set_title("PyBear Fare By Month")
ax.set_xlabel("Fare ($)")
ax.set_ylabel("Date")
ax.grid()

# %% [markdown]
# # Bar Charts 5.1.5 - XX

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
#Create the plot
plt.bar(x_axis,y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot.
plt.barh(y_axis, x_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot.
plt.barh(x_axis, y_axis,color="magenta",label="Boston")
# Invert y axis
plt.gca().invert_yaxis()
# Create labels for the x and y axes.
plt.xlabel("Fare($)")
plt.ylabel("Date")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis,color="k",label="New York")
plt.legend()

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis,color="c",label="Chicago")
# Create labels for the x and y axes.
plt.xlabel("Fare($)")
plt.ylabel("Date")
# Invert y axis
plt.gca().invert_yaxis()
# Add the legend.
plt.legend()

# %%
#Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %% [markdown]
# # Scatter Plots 5.1.7

# %%
plt.plot(x_axis, y_axis,"o")

# %%
plt.scatter(y_axis, x_axis, c="r", label="Chicago")
plt.title("PyBer Fare By Month")
# Invert y axis
plt.gca().invert_yaxis()
# Create labels for the x and y axes.
plt.xlabel("Fare($)")
plt.ylabel("Date")
# Set the x limit between 0 and 45.
plt.xlim(0, 50)
plt.legend()

# %%
y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*3)
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis,s=[i * 5 for i in y_axis],
           edgecolor="k", linewidth=2,color="skyblue",label="Boston")
plt.title("PyBer Fare By Month")
# Invert y axis
plt.gca().invert_yaxis()
# Create labels for the x and y axes.
plt.xlabel("Fare($)")
plt.ylabel("Date")
# Set the x limit between 0 and 45.
plt.xlim(0, 50)
plt.legend()

# %% [markdown]
# # Pie Charts 5.1.8

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
plt.subplots(figsize=(8, 8)) # Needs to be on the first line before defined axis
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, .5, 0, 0, 0, 0, 0)
plt.pie(y_axis, 
        explode=explode_values,
        colors = colors,
        labels=x_axis, 
        autopct='%.1f%%'
        rotatelables=90)
plt.show()
# Out:
#   File "C:\Users\lavec\AppData\Local\Temp/ipykernel_18520/915524694.py", line 9
#     rotatelables=90)
#     ^
# SyntaxError: invalid syntax

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax.pie(y_axis,
       labels=x_axis,
       shadow=True,
       explode=explode_values,
       labeldistance=1.19,
       #rotatelabels=90,
        colors = ["slateblue", "orchid", "lightblue", 
                  "green", "yellowgreen", "greenyellow", 
                   "goldenrod", "tan", "gold", "firebrick", 
                   "tomato", "slategrey"],
       wedgeprops={"linewidth":8},
       autopct='%.1f%%',
       startangle=80)
explode_values = (0, 0, .2, 0, 0, 0, .2, 0, 0, 0, 0, 0)
plt.gca().invert_xaxis()
plt.show()

# %% [markdown]
# # Error Bars

# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt
import statistics

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Get the standard deviation of the values in the y-axis.
stdev = statistics.stdev(y_axis)
mean = statistics.mean(y_axis)
stdev,mean
# Out:
# (11.208367917035753, 25.1825)

# %%
plt.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
fig, ax = plt.subplots()
ax.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
plt.bar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <BarContainer object of 12 artists>

# %%
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
import numpy as np
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
import numpy as np
np.arange(0, 51, step=10.0)
# Out:
# array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40., 45., 50.])

# %%
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))  # Can use y-ticks here are well if numerical
plt.show()

# %%
from matplotlib.ticker import MultipleLocator
# Increase the size of the plot figure.
fig, ax = plt.subplots(figsize=(8, 8))
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))

# Create minor ticks at an increment of 1.
ax.xaxis.set_minor_locator(MultipleLocator(1))
plt.show()
